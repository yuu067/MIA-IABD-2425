# %% [markdown]
# <a href="https://colab.research.google.com/github/yuu067/MIA-IABD-2425/blob/main/UD02/notebooks/EX3.-detectar_centrocampistes_joves_ES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sistema de lógica difusa para encontrar centrocampistas jovenes con un buen potencial
#
# Este ejemplo muestra cómo crear un sistema experto con lógica difusa para detectar centro-campistas jóvenes con buen potencial.Nos basaremos en el trabajo de Luka Radovanović, un estudiante de la Universidad de Belgrado. El resultado del trabajo se puede encontrar en: https://github.com/lukadlm97/football-manager-resching/tree/master

# %% [markdown]
# ## Planteamiento del problema
#
# Uno de los problemas que encuentran los equipos de fútbol es la detección de jugadores jóvenes con potencial. Es por eso que estamos creando un sistema expertos con lógica difusa que nos ayude a detectar centrocampistas ofensivos jóvenes con potencial.
#
# Hemos elegido la posición de un centrocampista ofensivo porque es una posición de lo más difícil de encontrar y, por lo tanto, es una posición que los equipos están buscando mucho.Además, es una posición en la que muchos de los mejores jugadores de la historia han jugado, como: Di Stefano, Maradona, Zidane, Platini, etc.

# %% [markdown]
# ## Pasos previos
#
# Necesitamos instalar la libreria scikit-fuzzy, pero no podemos usar la última versión (0.5), con la 0.4.2 es suficiente.

# %%
# %pip install scikit-fuzzy==0.4.2 #La libreria 0.5 es más reciente pero tiene problemas con el ControlSystem.view()
# Out:
# Collecting scikit-fuzzy==0.4.2
#   Downloading scikit-fuzzy-0.4.2.tar.gz (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy==0.4.2) (1.26.4)
# Requirement already satisfied: scipy>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy==0.4.2) (1.13.1)
# Requirement already satisfied: networkx>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy==0.4.2) (3.4.2)
# Building wheels for collected packages: scikit-fuzzy
#   Building wheel for scikit-fuzzy (setup.py) ... done
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894076 sha256=fcadc52fb771929f372d7c257918aecfbac9f62021d38cc03bcc1a7a65593e02
#   Stored in directory: /root/.cache/pip/wheels/4f/86/1b/dfd97134a2c8313e519bcebd95d3fedc7be7944db022094bc8
# Successfully built scikit-fuzzy
# Installing collected packages: scikit-fuzzy
# Successfully installed scikit-fuzzy-0.4.2

# %% [markdown]
# ## Anàlisi de les dades
#
# Primero cargamos los datos (`EX2.-players_22.csv`) y vemos cómo están estructurados.
# Cargaremos los datos en un DataFrame de datos de Pandas y observaremos las primeras filas.

# %%
import pandas as pd

df = pd.read_csv('EX2.-players_22.csv')
df
# Out:
# <ipython-input-5-c51e318d3d01>:3: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('EX2.-players_22.csv')
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# 1          R. Lewandowski                   Robert Lewandowski
# 2       Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 3               Neymar Jr        Neymar da Silva Santos Júnior
# 4            K. De Bruyne                      Kevin De Bruyne
# ...                   ...                                  ...
# 19234           Song Defu                                  宋德福
# 19235           C. Porter                      Caoimhin Porter
# 19236            N. Logue              Nathan Logue-Cunningham
# 19237           L. Rudden                          Luke Rudden
# 19238  E. Lalchhanchhuaha              Emanuel Lalchhanchhuaha
#
#       player_positions  overall  potential    value_eur  wage_eur  age  ...  \
# 0           RW, ST, CF       93         93   78000000.0  320000.0   34  ...
# 1                   ST       92         92  119500000.0  270000.0   32  ...
# 2               ST, LW       91         91   45000000.0  270000.0   36  ...
# 3              LW, CAM       91         91  129000000.0  270000.0   29  ...
# 4              CM, CAM       91         91  125500000.0  350000.0   30  ...
# ...                ...      ...        ...          ...       ...  ...  ...
# 19234              CDM       47         52      70000.0    1000.0   22  ...
# 19235               CM       47         59     110000.0     500.0   19  ...
# 19236               CM       47         55     100000.0     500.0   21  ...
# 19237               ST       47         60     110000.0     500.0   19  ...
# 19238              CAM       47         60     110000.0     500.0   19  ...
#
#         lcb    cb   rcb    rb    gk  \
# 0      50+3  50+3  50+3  61+3  19+3
# 1      60+3  60+3  60+3  61+3  19+3
# 2      53+3  53+3  53+3  60+3  20+3
# 3      50+3  50+3  50+3  62+3  20+3
# 4      69+3  69+3  69+3  75+3  21+3
# ...     ...   ...   ...   ...   ...
# 19234  46+2  46+2  46+2  48+2  15+2
# 19235  44+2  44+2  44+2  48+2  14+2
# 19236  45+2  45+2  45+2  47+2  12+2
# 19237  26+2  26+2  26+2  32+2  15+2
# 19238  41+2  41+2  41+2  45+2  16+2
#
#                                          player_face_url  \
# 0      https://cdn.sofifa.net/players/158/023/22_120.png
# 1      https://cdn.sofifa.net/players/188/545/22_120.png
# 2      https://cdn.sofifa.net/players/020/801/22_120.png
# 3      https://cdn.sofifa.net/players/190/871/22_120.png
# 4      https://cdn.sofifa.net/players/192/985/22_120.png
# ...                                                  ...
# 19234  https://cdn.sofifa.net/players/261/962/22_120.png
# 19235  https://cdn.sofifa.net/players/262/040/22_120.png
# 19236  https://cdn.sofifa.net/players/262/760/22_120.png
# 19237  https://cdn.sofifa.net/players/262/820/22_120.png
# 19238  https://cdn.sofifa.net/players/264/540/22_120.png
#
#                                     club_logo_url  \
# 0          https://cdn.sofifa.net/teams/73/60.png
# 1          https://cdn.sofifa.net/teams/21/60.png
# 2          https://cdn.sofifa.net/teams/11/60.png
# 3          https://cdn.sofifa.net/teams/73/60.png
# 4          https://cdn.sofifa.net/teams/10/60.png
# ...                                           ...
# 19234  https://cdn.sofifa.net/teams/112541/60.png
# 19235     https://cdn.sofifa.net/teams/445/60.png
# 19236  https://cdn.sofifa.net/teams/111131/60.png
# 19237  https://cdn.sofifa.net/teams/111131/60.png
# 19238  https://cdn.sofifa.net/teams/113040/60.png
#
#                                  club_flag_url  \
# 0          https://cdn.sofifa.net/flags/fr.png
# 1          https://cdn.sofifa.net/flags/de.png
# 2      https://cdn.sofifa.net/flags/gb-eng.png
# 3          https://cdn.sofifa.net/flags/fr.png
# 4      https://cdn.sofifa.net/flags/gb-eng.png
# ...                                        ...
# 19234      https://cdn.sofifa.net/flags/cn.png
# 19235      https://cdn.sofifa.net/flags/ie.png
# 19236      https://cdn.sofifa.net/flags/ie.png
# 19237      https://cdn.sofifa.net/flags/ie.png
# 19238      https://cdn.sofifa.net/flags/in.png
#
#                                 nation_logo_url  \
# 0      https://cdn.sofifa.net/teams/1369/60.png
# 1      https://cdn.sofifa.net/teams/1353/60.png
# 2      https://cdn.sofifa.net/teams/1354/60.png
# 3                                           NaN
# 4      https://cdn.sofifa.net/teams/1325/60.png
# ...                                         ...
# 19234                                       NaN
# 19235                                       NaN
# 19236                                       NaN
# 19237                                       NaN
# 19238                                       NaN
#
#                            nation_flag_url
# 0      https://cdn.sofifa.net/flags/ar.png
# 1      https://cdn.sofifa.net/flags/pl.png
# 2      https://cdn.sofifa.net/flags/pt.png
# 3      https://cdn.sofifa.net/flags/br.png
# 4      https://cdn.sofifa.net/flags/be.png
# ...                                    ...
# 19234  https://cdn.sofifa.net/flags/cn.png
# 19235  https://cdn.sofifa.net/flags/ie.png
# 19236  https://cdn.sofifa.net/flags/ie.png
# 19237  https://cdn.sofifa.net/flags/ie.png
# 19238  https://cdn.sofifa.net/flags/in.png
#
# [19239 rows x 110 columns]

# %% [markdown]
# También será útil para nosotros que nos describan los datos para conocer su distribución.

# %%
df.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   19239.000000  19239.000000  19239.000000  1.916500e+04   19178.000000
# mean   231468.086959     65.772182     71.079370  2.850452e+06    9017.989363
# std     27039.717497      6.880232      6.086213  7.613700e+06   19470.176724
# min        41.000000     47.000000     49.000000  9.000000e+03     500.000000
# 25%    214413.500000     61.000000     67.000000  4.750000e+05    1000.000000
# 50%    236543.000000     66.000000     71.000000  9.750000e+05    3000.000000
# 75%    253532.500000     70.000000     75.000000  2.000000e+06    8000.000000
# max    264640.000000     93.000000     95.000000  1.940000e+08  350000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  19239.000000  19239.000000  19239.000000   19178.000000  19178.000000
# mean      25.210822    181.299704     74.943032   50580.498123      1.354364
# std        4.748235      6.863179      7.069434   54401.868535      0.747865
# min       16.000000    155.000000     49.000000       1.000000      1.000000
# 25%       21.000000    176.000000     70.000000     479.000000      1.000000
# 50%       25.000000    181.000000     75.000000    1938.000000      1.000000
# 75%       29.000000    186.000000     80.000000  111139.000000      1.000000
# max       54.000000    206.000000    110.000000  115820.000000      5.000000
#
#        ...  mentality_composure  defending_marking_awareness  \
# count  ...         19239.000000                 19239.000000
# mean   ...            57.929830                    46.601746
# std    ...            12.159326                    20.200807
# min    ...            12.000000                     4.000000
# 25%    ...            50.000000                    29.000000
# 50%    ...            59.000000                    52.000000
# 75%    ...            66.000000                    63.000000
# max    ...            96.000000                    93.000000
#
#        defending_standing_tackle  defending_sliding_tackle  \
# count               19239.000000              19239.000000
# mean                   48.045584                 45.906700
# std                    21.232718                 20.755683
# min                     5.000000                  5.000000
# 25%                    28.000000                 25.000000
# 50%                    56.000000                 53.000000
# 75%                    65.000000                 63.000000
# max                    93.000000                 92.000000
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count        19239.000000          19239.000000         19239.000000
# mean            16.406102             16.192474            16.055356
# std             17.574028             16.839528            16.564554
# min              2.000000              2.000000             2.000000
# 25%              8.000000              8.000000             8.000000
# 50%             11.000000             11.000000            11.000000
# 75%             14.000000             14.000000            14.000000
# max             91.000000             92.000000            93.000000
#
#        goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed
# count             19239.000000          19239.000000        2132.000000
# mean                 16.229274             16.491814          36.439962
# std                  17.059779             17.884833          10.751563
# min                   2.000000              2.000000          15.000000
# 25%                   8.000000              8.000000          27.000000
# 50%                  11.000000             11.000000          36.000000
# 75%                  14.000000             14.000000          45.000000
# max                  92.000000             90.000000          65.000000
#
# [8 rows x 60 columns]

# %% [markdown]
# Como hemos dicho, estamos buscando un centro-campista ofensivo joven, por lo que eliminaremos a todos los jugadores que no juegan en esta posición (CAM - Center Attacking Midfielders) o tienen más de 24 años.

# %%
df = df[(df['player_positions'].str.contains('CAM')) & (df['age'] <= 24)]
df
# Out:
#        sofifa_id                                         player_url  \
# 138       235790  https://sofifa.com/player/235790/kai-havertz/2...
# 139       237692  https://sofifa.com/player/237692/phil-foden/22...
# 193       233064  https://sofifa.com/player/233064/mason-mount/2...
# 252       220697  https://sofifa.com/player/220697/james-maddiso...
# 254       222665  https://sofifa.com/player/222665/martin-odegaa...
# ...          ...                                                ...
# 19169     264072  https://sofifa.com/player/264072/bernardo-oliv...
# 19171     264142  https://sofifa.com/player/264142/aaron-doran/2...
# 19194     259649  https://sofifa.com/player/259649/engson-singh/...
# 19233     261818  https://sofifa.com/player/261818/ronan-gallagh...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                long_name player_positions  overall  \
# 138            K. Havertz        Kai Lukas Havertz      CAM, CF, CM       84
# 139              P. Foden             Philip Foden      CAM, LW, CM       84
# 193              M. Mount              Mason Mount      CAM, CM, RW       83
# 252           J. Maddison           James Maddison          CAM, CM       82
# 254           M. Ødegaard          Martin Ødegaard          CAM, CM       82
# ...                   ...                      ...              ...      ...
# 19169            Bernardo        Bernardo Oliveira              CAM       49
# 19171            A. Doran              Aaron Doran              CAM       49
# 19194            E. Singh             Engson Singh          CAM, CM       48
# 19233        R. Gallagher          Ronan Gallagher              CAM       47
# 19238  E. Lalchhanchhuaha  Emanuel Lalchhanchhuaha              CAM       47
#
#        potential   value_eur  wage_eur  age  ...   lcb    cb   rcb    rb  \
# 138           92  94500000.0  130000.0   22  ...  55+3  55+3  55+3  62+3
# 139           92  94500000.0  125000.0   21  ...  59+3  59+3  59+3  68+3
# 193           89  58500000.0  120000.0   22  ...  60+3  60+3  60+3  68+3
# 252           85  41500000.0  100000.0   24  ...  57+2  57+2  57+2  65+2
# 254           88  49000000.0   89000.0   22  ...  60+3  60+3  60+3  68+3
# ...          ...         ...       ...  ...  ...   ...   ...   ...   ...
# 19169         67    120000.0     500.0   17  ...  39+2  39+2  39+2  42+2
# 19171         62    110000.0     500.0   18  ...  42+2  42+2  42+2  44+2
# 19194         65    120000.0     500.0   18  ...  37+2  37+2  37+2  41+2
# 19233         61    110000.0     500.0   20  ...  39+2  39+2  39+2  41+2
# 19238         60    110000.0     500.0   19  ...  41+2  41+2  41+2  45+2
#
#          gk                                    player_face_url  \
# 138    17+3  https://cdn.sofifa.net/players/235/790/22_120.png
# 139    19+3  https://cdn.sofifa.net/players/237/692/22_120.png
# 193    19+3  https://cdn.sofifa.net/players/233/064/22_120.png
# 252    20+2  https://cdn.sofifa.net/players/220/697/22_120.png
# 254    19+3  https://cdn.sofifa.net/players/222/665/22_120.png
# ...     ...                                                ...
# 19169  14+2  https://cdn.sofifa.net/players/264/072/22_120.png
# 19171  14+2  https://cdn.sofifa.net/players/264/142/22_120.png
# 19194  12+2  https://cdn.sofifa.net/players/259/649/22_120.png
# 19233  15+2  https://cdn.sofifa.net/players/261/818/22_120.png
# 19238  16+2  https://cdn.sofifa.net/players/264/540/22_120.png
#
#                                     club_logo_url  \
# 138         https://cdn.sofifa.net/teams/5/60.png
# 139        https://cdn.sofifa.net/teams/10/60.png
# 193         https://cdn.sofifa.net/teams/5/60.png
# 252        https://cdn.sofifa.net/teams/95/60.png
# 254         https://cdn.sofifa.net/teams/1/60.png
# ...                                           ...
# 19169  https://cdn.sofifa.net/teams/111393/60.png
# 19171     https://cdn.sofifa.net/teams/305/60.png
# 19194  https://cdn.sofifa.net/teams/113146/60.png
# 19233  https://cdn.sofifa.net/teams/111131/60.png
# 19238  https://cdn.sofifa.net/teams/113040/60.png
#
#                                  club_flag_url  \
# 138    https://cdn.sofifa.net/flags/gb-eng.png
# 139    https://cdn.sofifa.net/flags/gb-eng.png
# 193    https://cdn.sofifa.net/flags/gb-eng.png
# 252    https://cdn.sofifa.net/flags/gb-eng.png
# 254    https://cdn.sofifa.net/flags/gb-eng.png
# ...                                        ...
# 19169      https://cdn.sofifa.net/flags/au.png
# 19171      https://cdn.sofifa.net/flags/ie.png
# 19194      https://cdn.sofifa.net/flags/in.png
# 19233      https://cdn.sofifa.net/flags/ie.png
# 19238      https://cdn.sofifa.net/flags/in.png
#
#                                 nation_logo_url  \
# 138    https://cdn.sofifa.net/teams/1337/60.png
# 139    https://cdn.sofifa.net/teams/1318/60.png
# 193    https://cdn.sofifa.net/teams/1318/60.png
# 252                                         NaN
# 254    https://cdn.sofifa.net/teams/1352/60.png
# ...                                         ...
# 19169                                       NaN
# 19171                                       NaN
# 19194                                       NaN
# 19233                                       NaN
# 19238                                       NaN
#
#                                nation_flag_url
# 138        https://cdn.sofifa.net/flags/de.png
# 139    https://cdn.sofifa.net/flags/gb-eng.png
# 193    https://cdn.sofifa.net/flags/gb-eng.png
# 252    https://cdn.sofifa.net/flags/gb-eng.png
# 254        https://cdn.sofifa.net/flags/no.png
# ...                                        ...
# 19169      https://cdn.sofifa.net/flags/br.png
# 19171      https://cdn.sofifa.net/flags/ie.png
# 19194      https://cdn.sofifa.net/flags/in.png
# 19233      https://cdn.sofifa.net/flags/ie.png
# 19238      https://cdn.sofifa.net/flags/in.png
#
# [1158 rows x 110 columns]

# %% [markdown]
# ## Análisis del potencial
#
# Para hacer una primera aproximación al potencial de los jugadores, hemos hecho una primera hipótesis que nos dice que los jugadores más potenciales son aquellos que son muy jóvenes y tienen una gran habilidad para pasar la pelota.
#
# Luego crearemos un sistema difuso con dos variables de entrada: la edad y la capacidad de pasar la pelota. La variable de salida será el potencial.
#
# El resumen de las reglas propuestas es el siguiente:
#
# ### Relación entre la edad y la categoría lingüística
#
# | Edad  | Categoría    |
# |-------|--------------|
# | 16-18 | Joven        |
# | 17-21 | Junior       |
# | 20-24 | Senior-joven |
#
# ### Relación entre la capacidad de pasar la pelota y la categoría lingüística
#
# | Pasar la pelota | Categoría   |
# |-----------------|-------------|
# | <=60            | Baja        |
# | 60-85           | Promedia    |
# | >=80-100        | Alta        |
#
# ### Relación entre la categoría lingüística de potencial y su valor numérico
#
# Las variables de salida serán triangulares.
#
# | Potencial | Valor numérico |
# |-----------|----------------|
# | Bajo      | <40            |
# | Promedio  | 10 - 90        |
# | Alto      | 60 - 100       |
#
# Define los antecedentes y la consecuencia con sus funciones de adhesión.

# %%
# define aquí los antecedentes y el consecuente y a continuación cada una de las funciones de pertenencia (edad, calidad_pasada, potencial)
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
edad = ctrl.Antecedent(np.arange(0, 25, 1), 'edad')
calidad_pasada = ctrl.Antecedent(np.arange(0, 101, 1), 'calidad_pasada')
potencial = ctrl.Consequent(np.arange(0, 101, 1), 'potencial')

# %%
# define la función de pertenencia para edad y visualizala
edad['joven'] = fuzz.trimf(edad.universe, [16, 16, 18])
edad['junior'] = fuzz.trimf(edad.universe, [16, 17, 21])
edad['senior'] = fuzz.trimf(edad.universe, [17, 24, 24])
edad.view()

# %%
# define la función de pertenencia para calidad_pasada y visualizala
calidad_pasada['baja'] = fuzz.trimf(calidad_pasada.universe, [0, 0, 60])
calidad_pasada['promedio'] = fuzz.trimf(calidad_pasada.universe, [30, 60, 85])
calidad_pasada['alta'] = fuzz.trimf(calidad_pasada.universe, [60, 90, 100])
calidad_pasada.view()

# %%
# define la función de pertenencia para potencial y visualizala
potencial['baja'] = fuzz.trimf(potencial.universe, [0, 20, 40])
potencial['promedio'] = fuzz.trimf(potencial.universe, [10, 50, 90])
potencial['alta'] = fuzz.trimf(potencial.universe, [60, 80, 100])
potencial.view()

# %% [markdown]
# ## Reglas
#
# Debemos definir las reglas que relacionan las variables de entrada con la variable de salida. Será lo siguiente:
#
# | Edad         | Calidad pasada | Potencial |
# |--------------|----------------|-----------|
# | Joven        | Alta           | Alto      |
# | Joven        | Promedia       | Promedio  |
# | Joven        | Baixa          | Promedio  |
# | Junior       | Alta           | Alto      |
# | Junior       | Promedia       | Promedio  |
# | Junior       | Baixa          | Bajo      |
# | Senior-joven | Alta           | Alto      |
# | Senior-joven | Promedia       | Bajo      |
# | Senior-joven | Baixa          | Bajo      |
#
# Cree las reglas para nuestro sistema y el sistema de control. Ver las dependencias.

# %%
# Define aquí las reglas
rule1 = ctrl.Rule(edad['joven'] & calidad_pasada['alta'], potencial['alta'])
rule2 = ctrl.Rule(edad['joven'] & calidad_pasada['promedio'], potencial['promedio'])
rule3 = ctrl.Rule(edad['joven'] & calidad_pasada['baja'], potencial['promedio'])
rule4 = ctrl.Rule(edad['junior'] & calidad_pasada['alta'], potencial['alta'])
rule5 = ctrl.Rule(edad['junior'] & calidad_pasada['promedio'], potencial['promedio'])
rule6 = ctrl.Rule(edad['junior'] & calidad_pasada['baja'], potencial['baja'])
rule7 = ctrl.Rule(edad['senior'] & calidad_pasada['alta'], potencial['alta'])
rule8 = ctrl.Rule(edad['senior'] & calidad_pasada['promedio'], potencial['baja'])
rule9 = ctrl.Rule(edad['senior'] & calidad_pasada['baja'], potencial['baja'])

# %%
# Añadelas al sistema de control

control = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])

# %%
# Visualizalas
control.view()

# %% [markdown]
# Antes de aplicar nuestro modelo a todos los datos que tenemos, debemos probarlo con un par de ejemplos.
# ¿Cuál será el potencial de un jugador de 17 años y un pase de 40? ¿Y si tuviera un pase de 80? También evalúa los dos casos anteriores si tenía 23 años.

# %%
# Realiza la simulación
simulacion = ctrl.ControlSystemSimulation(control)

# %%
# Carga los datos para el primer caso de prueba
simulacion.input['edad'] = 17
simulacion.input['calidad_pasada'] = 40

# %%
# Computa y visualiza la solución para la primera prueba
simulacion.compute()
print(simulacion.output['potencial'])
potencial.view(sim=simulacion)
# Out:
# 43.40277777777778

# %%
# Carga los datos para el segundo caso de prueba
simulacion.input['edad'] = 17
simulacion.input['calidad_pasada'] = 80

# %%
# Computa y visualiza la solución para la segunda prueba
simulacion.compute()
print(simulacion.output['potencial'])
potencial.view(sim=simulacion)
# Out:
# 65.2581168831169

# %%
# Carga los datos para el primer caso de prueba pero con 23 años
simulacion.input['edad'] = 23
simulacion.input['calidad_pasada'] = 40

# %%
# Computa y visualiza la solución para la primera prueba pero con 23 años
simulacion.compute()
print(simulacion.output['potencial'])
potencial.view(sim=simulacion)
# Out:
# 19.999999999999993

# %%
# Carga los datos para el segundo caso de prueba pero con 23 años
simulacion.input['edad'] = 23
simulacion.input['calidad_pasada'] = 80

# %%
# Computa y visualiza la solución para la segunda prueba pero con 23 años
simulacion.compute()
print(simulacion.output['potencial'])
potencial.view(sim=simulacion)
# Out:
# 62.704626334519595

# %% [markdown]
# ## Actualitzar el DataFrame
#
# Actualiza el DataFrame con los datos calculados por nuestro modelo. Crea una columna llamada "potencial" con los datos que hemos calculado.

# %%
# Crea la columna potencial con los datos que hemos calculado
# Out:
# <ipython-input-22-3fe053d09759>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['potencial'] = df.apply(potencial_jugador, axis=1)
#        sofifa_id                                         player_url  \
# 138       235790  https://sofifa.com/player/235790/kai-havertz/2...
# 139       237692  https://sofifa.com/player/237692/phil-foden/22...
# 193       233064  https://sofifa.com/player/233064/mason-mount/2...
# 252       220697  https://sofifa.com/player/220697/james-maddiso...
# 254       222665  https://sofifa.com/player/222665/martin-odegaa...
# ...          ...                                                ...
# 19169     264072  https://sofifa.com/player/264072/bernardo-oliv...
# 19171     264142  https://sofifa.com/player/264142/aaron-doran/2...
# 19194     259649  https://sofifa.com/player/259649/engson-singh/...
# 19233     261818  https://sofifa.com/player/261818/ronan-gallagh...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                long_name player_positions  overall  \
# 138            K. Havertz        Kai Lukas Havertz      CAM, CF, CM       84
# 139              P. Foden             Philip Foden      CAM, LW, CM       84
# 193              M. Mount              Mason Mount      CAM, CM, RW       83
# 252           J. Maddison           James Maddison          CAM, CM       82
# 254           M. Ødegaard          Martin Ødegaard          CAM, CM       82
# ...                   ...                      ...              ...      ...
# 19169            Bernardo        Bernardo Oliveira              CAM       49
# 19171            A. Doran              Aaron Doran              CAM       49
# 19194            E. Singh             Engson Singh          CAM, CM       48
# 19233        R. Gallagher          Ronan Gallagher              CAM       47
# 19238  E. Lalchhanchhuaha  Emanuel Lalchhanchhuaha              CAM       47
#
#        potential   value_eur  wage_eur  age  ...    cb   rcb    rb    gk  \
# 138           92  94500000.0  130000.0   22  ...  55+3  55+3  62+3  17+3
# 139           92  94500000.0  125000.0   21  ...  59+3  59+3  68+3  19+3
# 193           89  58500000.0  120000.0   22  ...  60+3  60+3  68+3  19+3
# 252           85  41500000.0  100000.0   24  ...  57+2  57+2  65+2  20+2
# 254           88  49000000.0   89000.0   22  ...  60+3  60+3  68+3  19+3
# ...          ...         ...       ...  ...  ...   ...   ...   ...   ...
# 19169         67    120000.0     500.0   17  ...  39+2  39+2  42+2  14+2
# 19171         62    110000.0     500.0   18  ...  42+2  42+2  44+2  14+2
# 19194         65    120000.0     500.0   18  ...  37+2  37+2  41+2  12+2
# 19233         61    110000.0     500.0   20  ...  39+2  39+2  41+2  15+2
# 19238         60    110000.0     500.0   19  ...  41+2  41+2  45+2  16+2
#
#                                          player_face_url  \
# 138    https://cdn.sofifa.net/players/235/790/22_120.png
# 139    https://cdn.sofifa.net/players/237/692/22_120.png
# 193    https://cdn.sofifa.net/players/233/064/22_120.png
# 252    https://cdn.sofifa.net/players/220/697/22_120.png
# 254    https://cdn.sofifa.net/players/222/665/22_120.png
# ...                                                  ...
# 19169  https://cdn.sofifa.net/players/264/072/22_120.png
# 19171  https://cdn.sofifa.net/players/264/142/22_120.png
# 19194  https://cdn.sofifa.net/players/259/649/22_120.png
# 19233  https://cdn.sofifa.net/players/261/818/22_120.png
# 19238  https://cdn.sofifa.net/players/264/540/22_120.png
#
#                                     club_logo_url  \
# 138         https://cdn.sofifa.net/teams/5/60.png
# 139        https://cdn.sofifa.net/teams/10/60.png
# 193         https://cdn.sofifa.net/teams/5/60.png
# 252        https://cdn.sofifa.net/teams/95/60.png
# 254         https://cdn.sofifa.net/teams/1/60.png
# ...                                           ...
# 19169  https://cdn.sofifa.net/teams/111393/60.png
# 19171     https://cdn.sofifa.net/teams/305/60.png
# 19194  https://cdn.sofifa.net/teams/113146/60.png
# 19233  https://cdn.sofifa.net/teams/111131/60.png
# 19238  https://cdn.sofifa.net/teams/113040/60.png
#
#                                  club_flag_url  \
# 138    https://cdn.sofifa.net/flags/gb-eng.png
# 139    https://cdn.sofifa.net/flags/gb-eng.png
# 193    https://cdn.sofifa.net/flags/gb-eng.png
# 252    https://cdn.sofifa.net/flags/gb-eng.png
# 254    https://cdn.sofifa.net/flags/gb-eng.png
# ...                                        ...
# 19169      https://cdn.sofifa.net/flags/au.png
# 19171      https://cdn.sofifa.net/flags/ie.png
# 19194      https://cdn.sofifa.net/flags/in.png
# 19233      https://cdn.sofifa.net/flags/ie.png
# 19238      https://cdn.sofifa.net/flags/in.png
#
#                                 nation_logo_url  \
# 138    https://cdn.sofifa.net/teams/1337/60.png
# 139    https://cdn.sofifa.net/teams/1318/60.png
# 193    https://cdn.sofifa.net/teams/1318/60.png
# 252                                         NaN
# 254    https://cdn.sofifa.net/teams/1352/60.png
# ...                                         ...
# 19169                                       NaN
# 19171                                       NaN
# 19194                                       NaN
# 19233                                       NaN
# 19238                                       NaN
#
#                                nation_flag_url  potencial
# 138        https://cdn.sofifa.net/flags/de.png  49.751276
# 139    https://cdn.sofifa.net/flags/gb-eng.png  51.697649
# 193    https://cdn.sofifa.net/flags/gb-eng.png  60.886335
# 252    https://cdn.sofifa.net/flags/gb-eng.png  63.118280
# 254        https://cdn.sofifa.net/flags/no.png  58.224722
# ...                                        ...        ...
# 19169      https://cdn.sofifa.net/flags/br.png  54.222222
# 19171      https://cdn.sofifa.net/flags/ie.png  53.611111
# 19194      https://cdn.sofifa.net/flags/in.png  53.611111
# 19233      https://cdn.sofifa.net/flags/ie.png  53.611111
# 19238      https://cdn.sofifa.net/flags/in.png  53.379630
#
# [1158 rows x 111 columns]

# %% [markdown]
# ## Conclusiones
#
# Si observamos los resultados, podemos concluir que nuestro modelo es bastante consistente, incluso si los números no son del todo realistas.
# ¿Cómo podemos mejorar el modelo? Agrega cierta mejora o basate en el trabajo de Luka Radovanović y comenta los resultados.

# %%
# Agrega las celdas de código que necesites

# %% [markdown]
# Agrega también las celdas de markdown que necesites para explicarlo

# %% [markdown]
# # Entrega
#
# Una vez completado el Notebook y ejecutado completamente (comprueba que funcionan todas las celdas) y añadidas las mejoras. Envialo a la tarea correspondiente de AULES.
